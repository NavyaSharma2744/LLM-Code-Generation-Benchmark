# %% [markdown]
# <a href="https://colab.research.google.com/github/NavyaSharma2744/LLM-Code-Generation-Benchmark/blob/main/notebooks/result_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("../results/benchmark_results.csv")
df

# %%
print("Columns in the results file:")
print(df.columns.tolist())

# %%
df_sorted = df.sort_values("pass@1", ascending=False)
df_sorted

# %%
best_model = df.sort_values("pass@1", ascending=False).iloc[0]

print("Best model based on pass@1:")
print(best_model)

# %%
df.describe()

# %%
summary = df[["model", "dataset", "compile_rate", "pass@1", "codebleu"]]
summary

# %%
summary.to_csv("../results/summary_results.csv", index=False)
print("Saved summary to ../results/summary_results.csv")
